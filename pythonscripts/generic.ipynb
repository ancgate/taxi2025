# %% [markdown]
# ## Installing Libraries

# %%
# !pip install azure-storage-blob
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.0/407.0 kB 15.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.1/207.1 kB 16.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Importing Libraries

# %%
import os, uuid
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient
import pandas as pd
import numpy as np
import json
import requests
import io

# %%
RESTAURANT_DOWNLOAD_URL = "https://data.cityofnewyork.us/api/views/43nn-pn8j/rows.csv?fourfour=43nn-pn8j&cacheBust=1744137254&date=20250408&accessType=DOWNLOAD"


response = requests.get(RESTAURANT_DOWNLOAD_URL)
df = pd.read_csv(io.StringIO(response.text))
df.head()
# Out:
#       CAMIS                       DBA      BORO BUILDING            STREET  \
# 0  41708809          HL SPRING GARDEN  Brooklyn     8706          5 AVENUE
# 1  50018884  DUNKIN', 'BASKIN ROBBINS    Queens     7302         AUSTIN ST
# 2  50063056         MASPETH CAFETERIA    Queens     4805         GRAND AVE
# 3  50098565      TARIM UYGHUR CUISINE    Queens   136-20  ROOSEVELT AVENUE
# 4  50106079   EL PALENQUE TRES GALLOS  Brooklyn      816          AVENUE U
#
#    ZIPCODE       PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0  11209.0  7189217171             Chinese      04/25/2024
# 1  11375.0  7185750892              Donuts      03/27/2025
# 2  11378.0  2016388280            American      06/22/2023
# 3  11354.0  6193650179             Chinese      10/03/2024
# 4  11223.0  6467446081             Mexican      07/26/2024
#
#                                               ACTION  ...  \
# 0    Violations were cited in the following area(s).  ...
# ...

# %%
RESTAURANT_DOWNLOAD_URL_JSON = "https://data.cityofnewyork.us/resource/erm2-nwe9.json"
resp = requests.get(RESTAURANT_DOWNLOAD_URL_JSON)
data = resp.json()
df_json = pd.DataFrame(data)
print(df_json.shape)
df_json.head(25)
# 64571486
# Out:
# (1000, 46)
#    unique_key             created_date agency  \
# 0    64571486  2025-04-07T01:51:12.000   NYPD
# 1    64570400  2025-04-07T01:51:01.000   NYPD
# 2    64571430  2025-04-07T01:50:38.000   NYPD
# 3    64571425  2025-04-07T01:49:56.000   NYPD
# 4    64576182  2025-04-07T01:49:26.000   NYPD
# 5    64570514  2025-04-07T01:48:37.000   NYPD
# 6    64575354  2025-04-07T01:47:59.000   NYPD
# 7    64574535  2025-04-07T01:47:20.000   NYPD
# 8    64571378  2025-04-07T01:47:12.000    TLC
# 9    64571286  2025-04-07T01:46:39.000   DSNY
# 10   64576330  2025-04-07T01:45:47.000   NYPD
# 11   64576409  2025-04-07T01:44:54.000   NYPD
# 12   64574293  2025-04-07T01:44:54.000   NYPD
# 13   64574292  2025-04-07T01:44:17.000   NYPD
# 14   64574388  2025-04-07T01:42:32.000   NYPD
# 15   64575322  2025-04-07T01:42:25.000   NYPD
# 16   64575346  2025-04-07T01:42:07.000   NYPD
# 17   64571484  2025-04-07T01:42:05.000   NYPD
# 18   64572373  2025-04-07T01:39:12.000   NYPD
# ...

# %%
RESTAURANT_DOWNLOAD_URL_JSON = "https://data.cityofnewyork.us/resource/erm2-nwe9.json?$limit=10&$offset=15"
resp = requests.get(RESTAURANT_DOWNLOAD_URL_JSON)
data = resp.json()
df_json = pd.DataFrame(data)
print(df_json.shape)
df_json.head(25)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-c562c49f2093> in <cell line: 0>()
#       1 RESTAURANT_DOWNLOAD_URL_JSON = "https://data.cityofnewyork.us/resource/erm2-nwe9.json?$limit=10&$offset=15"
# ----> 2 resp = requests.get(RESTAURANT_DOWNLOAD_URL_JSON)
#       3 data = resp.json()
#       4 df_json = pd.DataFrame(data)
#       5 print(df_json.shape)
#
# /usr/local/lib/python3.11/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.11/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ...

# %%
number_of_rows = 39570654
limit = 50000

for offset in range(0, number_of_rows, limit):
  RESTAURANT_DOWNLOAD_URL_JSON = f"https://data.cityofnewyork.us/resource/erm2-nwe9.json?$limit={limit}&$offset={offset}"
  print(RESTAURANT_DOWNLOAD_URL_JSON)
  resp = requests.get(RESTAURANT_DOWNLOAD_URL_JSON)
  data = resp.json()
# Out:
# https://data.cityofnewyork.us/resource/erm2-nwe9.json?$limit=50000&$offset=0
# https://data.cityofnewyork.us/resource/erm2-nwe9.json?$limit=50000&$offset=50000
# https://data.cityofnewyork.us/resource/erm2-nwe9.json?$limit=50000&$offset=100000
# https://data.cityofnewyork.us/resource/erm2-nwe9.json?$limit=50000&$offset=150000
# https://data.cityofnewyork.us/resource/erm2-nwe9.json?$limit=50000&$offset=200000
# https://data.cityofnewyork.us/resource/erm2-nwe9.json?$limit=50000&$offset=250000
# https://data.cityofnewyork.us/resource/erm2-nwe9.json?$limit=50000&$offset=300000
# https://data.cityofnewyork.us/resource/erm2-nwe9.json?$limit=50000&$offset=350000
# https://data.cityofnewyork.us/resource/erm2-nwe9.json?$limit=50000&$offset=400000
# https://data.cityofnewyork.us/resource/erm2-nwe9.json?$limit=50000&$offset=450000
# https://data.cityofnewyork.us/resource/erm2-nwe9.json?$limit=50000&$offset=500000
# ...
